# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
HADK_DF = pd.read_csv('Datasets\Heart_attack_dataset_kaggle.csv')

# %%
HFCRD_DF = pd.read_csv('Datasets\heart_failure_clinical_records_dataset.csv')

# %%
HRT_DF = pd.read_excel('Datasets\heart.xlsx')

# %%
HDU_DF = pd.read_excel('Datasets\heart_disease_uci.xlsx')

# %%
# !dir Datasets
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is 28A4-591E
#
#  Directory of C:\Users\Mia\OneDrive\Documents\GitHub\Final_Project\Datasets
#
# 06/28/2021  05:29 PM    <DIR>          .
# 06/28/2021  05:29 PM    <DIR>          ..
# 06/13/2021  11:50 PM            27,743 heart.xlsx
# 06/10/2021  10:30 PM            11,323 Heart_attack_dataset_kaggle.csv
# 06/13/2021  11:40 PM            69,062 heart_disease_uci.xlsx
# 06/13/2021  11:27 PM            12,539 heart_failure_clinical_records_dataset.csv
#                4 File(s)        120,667 bytes
#                2 Dir(s)  161,250,926,592 bytes free

# %%
HADK_DF.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %% [markdown]
# ## Correlation Matrix

# %%
HADK_DF.corr(method='pearson')
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trtbps    0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalachh -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exng      0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slp      -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# caa       0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thall     0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %% [markdown]
# ## Legend
#
# age	sex	cp=chest pain	trtbps=resting blood pressure	chol	fbs=fasting blood sugar	restecg=resting electrocardiographic results	thalachh=maximum heart rate achieved	exng=exercise induced angina	oldpeak	slp	caa	thall	output

# %%
HADK_DF.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'), axis=1)
# Out:
# <style  type="text/css" >
# #T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow0_col0,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow1_col1,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow2_col2,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow3_col3,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow4_col4,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow5_col5,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow6_col6,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow7_col7,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow8_col8,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow9_col9,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow10_col10,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow11_col11,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow12_col12,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow13_col13{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow0_col1,#T_091949c0_05e1_11ec_bb3a_94e70b349dcdrow6_col10{
#             background-color:  #80a3fa;
#             color:  #000000;
# ...

# %%
HFCRD_DF.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
HRT_DF.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
HDU_DF.head()
# Out:
#    id  age     sex    dataset               cp  trestbps   chol  fbs  \
# 0   1   63    Male  Cleveland   typical angina     145.0  233.0  1.0
# 1   2   67    Male  Cleveland     asymptomatic     160.0  286.0  0.0
# 2   3   67    Male  Cleveland     asymptomatic     120.0  229.0  0.0
# 3   4   37    Male  Cleveland      non-anginal     130.0  250.0  0.0
# 4   5   41  Female  Cleveland  atypical angina     130.0  204.0  0.0
#
#           restecg  thalch  exang  oldpeak        slope   ca  \
# 0  lv hypertrophy   150.0    0.0      2.3  downsloping  0.0
# 1  lv hypertrophy   108.0    1.0      1.5         flat  3.0
# 2  lv hypertrophy   129.0    1.0      2.6         flat  2.0
# 3          normal   187.0    0.0      3.5  downsloping  0.0
# 4  lv hypertrophy   172.0    0.0      1.4    upsloping  0.0
#
#                 thal  num
# 0       fixed defect    0
# 1             normal    2
# 2  reversable defect    1
# 3             normal    0
# 4             normal    0
