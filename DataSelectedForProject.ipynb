# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pyreadstat as sas

# %%
conda install -c conda-forge pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# Solving environment: ...working... done
#
#
# ## Package Plan ##
#
#   environment location: C:\Users\Mia\anaconda3
#
#   added / updated specs:
#     - pyreadstat
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.10.3               |   py38haa244fe_0         3.1 MB  conda-forge
#     pyreadstat-1.1.2           |   py38heb50f4f_0         1.2 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   pyreadstat         conda-forge/win-64::pyreadstat-1.1.2-py38heb50f4f_0
#   python_abi         conda-forge/win-64::python_abi-3.8-2_cp38
#
# ...

# %%
CHD = pd.read_csv('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/CHD_preprocessed.csv')

# %%
CHD.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39          1              0         0.0     0.0                0
# 1     0   46          0              0         0.0     0.0                0
# 2     1   48          0              1        20.0     0.0                0
# 3     0   61          1              1        30.0     0.0                0
# 4     0   46          1              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f21cb1cbdb4d> in <module>
# ----> 1 unique(CHD)
#
# NameError: name 'unique' is not defined

# %% [markdown]
# ### Data is from Kaggle:
# ### https://www.kaggle.com/captainozlem/framingham-chd-preprocessed-data

# %%
NIH_Farm = pd.read_excel('C:/Users/Mia/Downloads/FRAMINGHAM_teaching_2019a/excel/frmgham2.xls')

# %%
NIH_Farm.head()
# Out:
#    RANDID  SEX  TOTCHOL  AGE  SYSBP  DIABP  CURSMOKE  CIGPDAY    BMI  \
# 0    2448    1    195.0   39  106.0   70.0         0      0.0  26.97
# 1    2448    1    209.0   52  121.0   66.0         0      0.0    NaN
# 2    6238    2    250.0   46  121.0   81.0         0      0.0  28.73
# 3    6238    2    260.0   52  105.0   69.5         0      0.0  29.43
# 4    6238    2    237.0   58  108.0   66.0         0      0.0  28.50
#
#    DIABETES  ...  CVD  HYPERTEN  TIMEAP  TIMEMI  TIMEMIFC  TIMECHD  TIMESTRK  \
# 0         0  ...    1         0    8766    6438      6438     6438      8766
# 1         0  ...    1         0    8766    6438      6438     6438      8766
# 2         0  ...    0         0    8766    8766      8766     8766      8766
# 3         0  ...    0         0    8766    8766      8766     8766      8766
# 4         0  ...    0         0    8766    8766      8766     8766      8766
#
#    TIMECVD  TIMEDTH  TIMEHYP
# 0     6438     8766     8766
# ...

# %% [markdown]
# ### The following is all from https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_BMX.htm
# ### and is going to be organized into one dataframe table after keeping columns we want

# %%
body = pd.read_sas('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_BMX.XPT')

# %%
body.head()
# Out:
#        SEQN  BMDSTATS  BMXWT  BMIWT  BMXRECUM  BMIRECUM  BMXHEAD  BMIHEAD  \
# 0  109263.0       4.0    NaN    NaN       NaN       NaN      NaN      NaN
# 1  109264.0       1.0   42.2    NaN       NaN       NaN      NaN      NaN
# 2  109265.0       1.0   12.0    NaN      91.6       NaN      NaN      NaN
# 3  109266.0       1.0   97.1    NaN       NaN       NaN      NaN      NaN
# 4  109269.0       3.0   13.6    NaN      90.9       NaN      NaN      NaN
#
#    BMXHT  BMIHT  ...  BMXLEG  BMILEG  BMXARML  BMIARML  BMXARMC  BMIARMC  \
# 0    NaN    NaN  ...     NaN     NaN      NaN      NaN      NaN      NaN
# 1  154.7    NaN  ...    36.3     NaN     33.8      NaN     22.7      NaN
# 2   89.3    NaN  ...     NaN     NaN     18.6      NaN     14.8      NaN
# 3  160.2    NaN  ...    40.8     NaN     34.7      NaN     35.8      NaN
# 4    NaN    1.0  ...     NaN     NaN      NaN      1.0      NaN      1.0
#
#    BMXWAIST  BMIWAIST  BMXHIP  BMIHIP
# 0       NaN       NaN     NaN     NaN
# ...

# %%
bpchol = pd.read_sas('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_BPQ.XPT')

# %%
bpchol.head()
# Out:
#        SEQN  BPQ020  BPQ030  BPD035  BPQ040A  BPQ050A  BPQ080  BPQ060  BPQ070  \
# 0  109266.0     2.0     NaN     NaN      NaN      NaN     1.0     NaN     1.0
# 1  109267.0     2.0     NaN     NaN      NaN      NaN     2.0     1.0     2.0
# 2  109268.0     2.0     NaN     NaN      NaN      NaN     2.0     9.0     NaN
# 3  109271.0     2.0     NaN     NaN      NaN      NaN     1.0     NaN     1.0
# 4  109273.0     2.0     NaN     NaN      NaN      NaN     2.0     1.0     4.0
#
#    BPQ090D  BPQ100D
# 0      2.0      NaN
# 1      2.0      NaN
# 2      NaN      NaN
# 3      1.0      1.0
# 4      2.0      NaN

# %%
bp = pd.read_sas('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_BPXO.XPT')

# %%
bp.head()
# Out:
#        SEQN BPAOARM  BPAOCSZ  BPXOSY1  BPXODI1  BPXOSY2  BPXODI2  BPXOSY3  \
# 0  109264.0    b'R'      3.0    109.0     67.0    109.0     68.0    106.0
# 1  109266.0    b'R'      4.0     99.0     56.0     99.0     55.0     99.0
# 2  109270.0    b'R'      3.0    123.0     73.0    124.0     77.0    127.0
# 3  109271.0    b'R'      4.0    102.0     65.0    108.0     68.0    111.0
# 4  109273.0    b'R'      3.0    116.0     68.0    110.0     66.0    115.0
#
#    BPXODI3  BPXOPLS1  BPXOPLS2  BPXOPLS3
# 0     66.0      94.0      95.0      91.0
# 1     52.0      68.0      66.0      66.0
# 2     70.0      95.0      98.0      93.0
# 3     68.0      73.0      71.0      70.0
# 4     68.0      71.0      70.0      70.0

# %%
pdemo = pd.read_sas('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_DEMO.XPT')

# %%
pdemo.head()
# Out:
#        SEQN  SDDSRVYR  RIDSTATR  RIAGENDR  RIDAGEYR  RIDAGEMN  RIDRETH1  \
# 0  109263.0      66.0       2.0       1.0       2.0       NaN       5.0
# 1  109264.0      66.0       2.0       2.0      13.0       NaN       1.0
# 2  109265.0      66.0       2.0       1.0       2.0       NaN       3.0
# 3  109266.0      66.0       2.0       2.0      29.0       NaN       5.0
# 4  109267.0      66.0       1.0       2.0      21.0       NaN       2.0
#
#    RIDRETH3  RIDEXMON  DMDBORN4  ...  FIAINTRP  MIALANG  MIAPROXY  MIAINTRP  \
# 0       6.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 1       1.0       2.0       1.0  ...       2.0      1.0       2.0       2.0
# 2       3.0       2.0       1.0  ...       2.0      NaN       NaN       NaN
# 3       6.0       2.0       2.0  ...       2.0      1.0       2.0       2.0
# 4       2.0       NaN       2.0  ...       2.0      NaN       NaN       NaN
#
#    AIALANGA      WTINTPRP      WTMECPRP  SDMVPSU  SDMVSTRA  INDFMPIR
# ...

# %%
dm = pd.read_sas('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_DIQ.XPT')

# %%
dm.head()
# Out:
#        SEQN  DIQ010  DID040  DIQ160  DIQ180  DIQ050  DID060  DIQ060U  DIQ070  \
# 0  109263.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN     NaN
# 1  109264.0     2.0     NaN     2.0     2.0     NaN     NaN      NaN     NaN
# 2  109265.0     2.0     NaN     NaN     NaN     NaN     NaN      NaN     NaN
# 3  109266.0     2.0     NaN     1.0     1.0     NaN     NaN      NaN     2.0
# 4  109267.0     2.0     NaN     2.0     2.0     NaN     NaN      NaN     NaN
#
#    DIQ230  ...  DIQ300D  DID310S  DID310D  DID320  DID330  DID341  DID350  \
# 0     NaN  ...      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 1     NaN  ...      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 2     NaN  ...      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 3     NaN  ...      NaN      NaN      NaN     NaN     NaN     NaN     NaN
# 4     NaN  ...      NaN      NaN      NaN     NaN     NaN     NaN     NaN
#
#    DIQ350U  DIQ360  DIQ080
# 0      NaN     NaN     NaN
# ...

# %%
glu = pd.read_sas('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_GLU.XPT')

# %%
glu.head()
# Out:
#        SEQN      WTSAFPRP  LBXGLU  LBDGLUSI
# 0  109264.0  27533.174559    97.0      5.38
# 1  109271.0  18100.965319   103.0      5.72
# 2  109274.0  16281.758327   154.0      8.55
# 3  109277.0  32230.046209    92.0      5.11
# 4  109282.0  79007.100787    95.0      5.27

# %%
fastgbs, meta_fastgbs = sas.read_xport('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/P_GLU.XPT')

# %%
meta_fastgbs.column_names_to_labels
# Out:
# {'SEQN': 'Respondent sequence number',
#  'WTSAFPRP': 'Fasting Subsample Weight',
#  'LBXGLU': 'Fasting Glucose (mg/dL)',
#  'LBDGLUSI': 'Fasting Glucose (mmol/L)'}

# %% [markdown]
# ### The rest of the data is from:
# ### https://wwwn.cdc.gov/Nchs/Nhanes/2017-2018/P_BMX.htm
# ### it looks crazy but we are keeping certain columns from each dataframe and forming one dataframe overall

# %% [markdown]
# #### Below is back up dataset for stroke prediction at kaggle
# #### https://www.kaggle.com/fedesoriano/stroke-prediction-dataset

# %%
stroke = pd.read_csv('C:/Users/Mia/OneDrive/Documents/GitHub/Final_Project/Datasets/kaggle-stroke.csv')

# %%
stroke.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
